# %% [markdown]
# <a href="https://colab.research.google.com/github/rafa218/03MIAR-Algoritmos-de-Optimizacion-2023/blob/main/AG2_Rafael_Ramirez.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Actividad Guiada 2**
#
# **Rafael Ernesto Ramírez Ruiz**

# %%
import math
import matplotlib.pyplot as plt
import numpy as np
import random

f=lambda X: X[0]**2+X[1]**2
df= lambda X: [2*X[0],2*X[1]]

#Preparando datos para mapa de nivel
resolucion=30
rango=2.5
X=np.linspace(-rango,rango,resolucion)
Y=np.linspace(-rango,rango,resolucion)
Z=np.zeros((resolucion,resolucion))

for ix, x in enumerate (X):
  for iy, y in enumerate (Y):
    Z[ix,iy]=f([x,y])


#Grafica de mapa de nivel Z
plt.contourf(X,Y,Z,resolucion)
plt.colorbar()

#Punto aleatorio inicial
P=[random.uniform(-2,2),random.uniform(-2,2)]
plt.plot(P[0],P[1],"o",c="white")

#Tasa de aprendizaje
TA=0.1

#Iteraciones
for _ in range(500):
  grad=df(P)

  P[0],P[1]=P[0]-TA*grad[0], P[1]-TA*grad[1]
  plt.plot(P[0],P[1],"o",c="red")

plt.plot(P[0],P[1],"o",c="green")
plt.show()
print("Solucion:", P, f(P))
# Out:
# Solucion: [-6.2669101972604264e-49, 3.491342232906706e-49] 5.14636340078047e-97

# %% [markdown]
# # **Otra función**

# %%
f= lambda X: np.sin(1/2*X[0]**2-1/4*X[1]**2+3)*np.cos(2*X[0]+1-np.e**X[1])

#Preparando datos para mapa de nivel
resolucion=30
rango=2.5
X=np.linspace(-rango,rango,resolucion)
Y=np.linspace(-rango,rango,resolucion)
Z=np.zeros((resolucion,resolucion))

for ix, x in enumerate (X):
  for iy, y in enumerate (Y):
    Z[ix,iy]=f([x,y])


#Grafica de mapa de nivel Z
plt.contourf(X,Y,Z,resolucion)
plt.colorbar()


def df(Punto):
  h=0.01
  T=np.copy(Punto)
  grad=np.zeros(2)
  for it, th in enumerate (Punto):
    T[it]=T[it]+h
    grad[it]=(f(T)-f(Punto))/h
  return grad


P=[random.uniform(-2,2),random.uniform(-2,2)]

#Tasa de aprendizaje
TA=0.1

#Iteraciones
for _ in range(500):
  grad=df(P)

  P[0],P[1]=P[0]-TA*grad[0], P[1]-TA*grad[1]
  plt.plot(P[0],P[1],"o",c="red")

plt.plot(P[0],P[1],"o",c="green")
plt.show()
print("Solucion:", P, f(P))
# Out:
# Solucion: [0.29029103494959474, 1.5884347142361592] -0.6569867369208681
